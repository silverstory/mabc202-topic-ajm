# %% [markdown]
# ## **How to Determine Pre-test and Post-test**
# #### **MABC 202 - STATISTICS WITH COMPUTER APPLICATION**
# #### **Adviser: Dr. Ramon Narciso Daludado Sr., DBM**
# ---
# #### By: April J. Medina, MIT Student
# #### First Semester S.Y. 2024-2025
# ### **Our Lady of Fatima University, Graduate School**

# %% [markdown]
# ---
#
# ### **What is a Pre-Test?**
#
# - A **pre-test** is an evaluation given to participants before they undergo an intervention. It provides a baseline for their initial knowledge or state.
# - For example, in a classroom, pre-tests help assess the initial level of knowledge or skills. A pre-test on algebra can show how much students know before starting the subject, allowing comparison to the post-test results to assess changes.

# %% [markdown]
# ---
#
# ### **What is a Post-Test?**
#
# - A **post-test** is an evaluation given to participants after completing an intervention to assess the changes or improvements.
# - The post-test helps determine the effectiveness of the intervention by comparing results with the pre-test.
# - **Example (Student Context):**
#   After completing the math course, students take a post-test to evaluate what they’ve learned, and comparing the scores reveals their progress.

# %% [markdown]
# ---
#
# ### **Why Compare Pre-Test and Post-Test?**
#
# - Comparing pretest and posttest scores helps determine the effectiveness of an intervention or program.
# - This comparison shows whether the participants have improved, indicating the success of the intervention.
# - It reveals if the intervention or program was effective by measuring the improvement.
# - **Example (Student Context):**
#   In a school, comparing pre-test and post-test results from a science lesson can reveal how much students learned during the class.

# %% [markdown]
# ---
#
# ### **Relevant Formulas**
#
# - **Mean Calculation:**
#   The arithmetic mean is calculated by summing all the scores and dividing by the number of scores.
#
#   ![image-3.png](attachment:image-3.png)
#
#   ![image.png](attachment:image.png)
#
#   ## Example pre-test scores:
#
#   ![image-2.png](attachment:image-2.png)
#
#   ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ---
#
# ### **T-Test Formula:**
# - Used to compare the means of two sets of data, like pre-test and post-test scores, to check if the difference is significant.
#
# #### Choosing the right t-test formula:
#
#   ![image-17.png](attachment:image-17.png)
#
#   ![image-18.png](attachment:image-18.png)
#
# ### One-sample, two-sample, or paired t test?
#
# - If the groups come from a single population (e.g., measuring before and after an experimental treatment), perform a paired t test. This is a [within-subjects design]().
#    - In a within-subjects design, or a within-groups design, all participants take part in every condition. It’s the opposite of a between-subjects design, where each participant experiences only one condition.
#    - A within-subjects design is also called a dependent groups or repeated measures design because researchers compare related measures from the same participants between different conditions.
#
# - If the groups come from two different populations (e.g., two different species, or people from two separate cities), perform a two-sample t test (a.k.a. independent t test). This is a between-subjects design.
#
# - If there is one group being compared against a standard value (e.g., comparing the acidity of a liquid to a neutral pH of 7), perform a one-sample t test.
#
# #### One-tailed or two-tailed t test?
#
# - If you only care whether the two populations are different from one another, perform a two-tailed t test.
# - If you want to know whether one population mean is greater than or less than the other, perform a one-tailed t test.
#
# ---
#
# #### <i>Since our data is collected from a **single population** and follows a **within-subjects design**, we will use a paired t-test to analyze it.</i>

# %% [markdown]
# ---
#
# ### **Paired t-Test calculation against our sample data**
#
# When conducting a paired t-test, we collect two sets of data from the same group of participants. For example:
# - **Pre-Test Scores**: Scores before an intervention (e.g., training, course).
# - **Post-Test Scores**: Scores after the intervention.
#
# ---
#
# We will compare the pre-test and post-test scores of three students using the **paired t-test**. The scores are:
#
# - **Pre-test scores**: \(80, 85, 90\)
# - **Post-test scores**: \(82, 88, 94\)
#
# ### **Paired t-Test Formula**
#
# The formula for the paired t-test is:
#
# ![image.png](attachment:image.png)
#
# Where:
#
# ![image-2.png](attachment:image-2.png)
#
# ### **Step 1: Gather Your Data**
#
# We have two sets of scores:
#
# - **Pre-test scores**: \(80, 85, 90\)
# - **Post-test scores**: \(82, 88, 94\)
#
# ### **Step 2: Calculate the Differences**
#
# For each student, we need to calculate the difference **<i>d sub i</i>** between their post-test and pre-test scores:
#
# ![image-3.png](attachment:image-3.png)
#
# | Student | Pre-test | Post-test | Difference (\(d_i\)) |
# |---------|----------|-----------|---------------------|
# | 1       | 80       | 82        | \(82 - 80 = 2\)     |
# | 2       | 85       | 88        | \(88 - 85 = 3\)     |
# | 3       | 90       | 94        | \(94 - 90 = 4\)     |
#
# Thus, the differences are:
#
# ![image-4.png](attachment:image-4.png)
#
# ### **Step 3: Calculate the Mean of the Differences ( <i>d-bar</i> )**
#
# Next, we calculate the mean of these differences:
#
# ![image-5.png](attachment:image-5.png)
#
# Where \(n\) is the number of pairs (in this case, \(n = 3\)).
#
# ![image-6.png](attachment:image-6.png)
#
# ### **Step 4: Calculate the Standard Deviation of the Differences ( <i>Sd</i> )**
#
# Now, we need to calculate the standard deviation of the differences. The formula is:
#
# ![image-7.png](attachment:image-7.png)
#
# ---
#
# <i>This formula is for calculating the **sample standard deviation** for **ungrouped data**. It measures the dispersion of individual data points **( d-sub-i )** from the mean **( d-bar )**. In grouped data, the formula would include frequency **( f )** to account for the number of occurrences of each value or group.</i>
#
# ---
#
# **Where:**
#
# ![image-8.png](attachment:image-8.png)
#
# ---
#
# ### Why Use \(N - 1\) in Sample Standard Deviation?
#
# When calculating the **sample standard deviation**, we use \(N - 1\) instead of \(N\) due to a concept called **Bessel's correction**. Here’s a simple breakdown:
#
# 1. **Sample vs. Population**:
#    - A **sample** is a small part of a larger **population**. We want to estimate how spread out the entire population is based on this small sample.
#    - If we divide by \(N\) (the total number of sample data points), we might **underestimate** the population's variability because a small sample tends to be less spread out.
#
# 2. **Bessel’s Correction**:
#    - By subtracting **1** from \(N\), we adjust our calculation to give a more accurate estimate of the population's standard deviation. This adjustment is known as **Bessel's correction**.
#
# 3. **Degrees of Freedom**:
#    - Subtracting **1** relates to **degrees of freedom**. When we calculate the mean, we use one degree of freedom since the mean is based on our sample data. This leaves us with \(N - 1\) independent pieces of data to work with.
#
# ### Intuition:
# Subtracting **1** allows the standard deviation to be slightly larger, which helps account for the limitations of using a sample. Without this correction, our estimate of the population standard deviation would be too small.
#
# In summary, using \(N - 1\) helps ensure we don’t underestimate the true variability in the population based on our sample data.
#
# ---
#
# ### Let's proceed with the calculation steps for Sd:
#
# 1. Calculate each ( individual differences - mean of differences ) squared:
#
#    ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# 2. Now sum these squared differences:
#
#    ![image-11.png](attachment:image-11.png)
#
# 3. Substitute into the standard deviation formula:
#
#    ![image-12.png](attachment:image-12.png)
#
# ### **Step 5: Calculate the t-Statistic**
#
# Now we can plug our values into the paired t-test formula:
#
# <!-- ![image-13.png](attachment:image-13.png)-->
#
#    ![image-14.png](attachment:image-14.png)
#
# Substituting in our calculated values:
#
#    ![image-15.png](attachment:image-15.png)
#
# ### **Results interpretation:**
#
# We found a mean difference of \(3\) and a standard deviation of the differences of \(1\). The calculated t-statistic is approximately \(5.196\). This suggests that there is a significant difference in scores before and after the intervention, indicating that the intervention had a positive impact on student performance.

# %% [markdown]
# ---
#
# ### **What Happens If There’s No Improvement?**
#
# - **No Change?** – If your Pretest and Post-Test scores are the same, the change didn’t make a difference.
#   - No improvement still provides valuable insight. It tells us that the change might not be effective, and that’s part of learning. We can use this information to re-evaluate and adjust our approach.
#
# - **Negative Change?** – If your Post-Test score is lower, the change might have had an unexpected negative effect.
#   - A negative result doesn’t mean failure. It helps us understand what doesn’t work, which is just as important as knowing what does. This outcome signals an opportunity to try something new or tweak the experiment.

# %% [markdown]
# ---
#
# ### **Visualizing Pre-Test and Post-Test Results**
#
# #### **1. Generate Sample Data using Python:**

# %%
# Simulated dataset for pretest and posttest scores
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats


pd.options.mode.chained_assignment = None  # default='warn'

# Generating Random Sample Data
np.random.seed(0)
student_ids = np.arange(1, 31)
pre_test_scores = np.random.randint(40, 80, 30)
post_test_scores = pre_test_scores + np.random.randint(-5, 15, 30)

# Creating a DataFrame
df = pd.DataFrame({'Student-Id': student_ids, 'Pre-Test': pre_test_scores, 'Post-Test': post_test_scores})

# Display the Data
print(df)
# Out:
#     Student-Id  Pre-Test  Post-Test
# 0            1        40         38
# 1            2        43         55
# 2            3        43         57
# 3            4        79         93
# 4            5        49         63
# 5            6        59         68
# 6            7        61         63
# 7            8        76         71
# 8            9        63         59
# 9           10        46         50
# 10          11        64         59
# 11          12        64         69
# 12          13        52         50
# 13          14        41         47
# 14          15        78         91
# 15          16        79         76
# 16          17        63         58
# 17          18        64         59
# 18          19        57         56
# 19          20        77         77
# 20          21        65         66
# 21          22        53         56
# 22          23        48         60
# 23          24        49         59
# 24          25        60         59
# ...

# %% [markdown]
# ---
#
# #### **2. Calculate the Mean and Standard Deviation:**

# %%
# Calculating Mean
pre_mean = df['Pre-Test'].mean()
post_mean = df['Post-Test'].mean()

# Calculating Standard Deviation
pre_std = df['Pre-Test'].std()
post_std = df['Post-Test'].std()

print(f"Pre-Test Mean: {pre_mean}, Post-Test Mean: {post_mean}")
print(f"Pre-Test Standard Deviation: {pre_std}, Post-Test Standard Deviation: {post_std}")
# Out:
# Pre-Test Mean: 57.56666666666667, Post-Test Mean: 60.53333333333333
# Pre-Test Standard Deviation: 12.062147499465034, Post-Test Standard Deviation: 12.582783347956411

# %% [markdown]
# ---
#
# #### **3. Perform a t-Test to Determine Significance:**

# %%
from scipy import stats

# Paired t-test
t_stat, p_value = stats.ttest_rel(df['Pre-Test'], df['Post-Test'])

print(f"t-Statistic: {t_stat}, p-value: {p_value}")
# Out:
# t-Statistic: -2.4603043670100675, p-value: 0.02007893224154974

# %% [markdown]
# **Results:**
# - The mean, standard deviation, and t-test results allow you to analyze whether the difference in scores is statistically significant.
# - If the p-value is less than 0.05, the result is significant, indicating that the post-test improvement is not due to chance.

# %% [markdown]
# ---
#
# ### **Scatter Plot Showing Changes from Pretest to Posttest Scores**

# %%
# Scatter plot of pretest and posttest scores
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Pre-Test', y='Post-Test', data=df, hue='Student-Id', palette='coolwarm')
plt.title('Scatter Plot of Pretest vs Posttest Scores')
plt.show()

# %%
# Mean Calculation
pre_mean = np.mean(df['Pre-Test'])
post_mean = np.mean(df['Post-Test'])

# Standard Deviation Calculation using ddof=1 for sample standard deviation
pre_std = np.std(df['Pre-Test'], ddof=1) # degree of freedom = 1
post_std = np.std(df['Post-Test'], ddof=1)

# Degrees of freedom are the number of independent variables that can be estimated
# in a statistical analysis and tell you how many items can be randomly selected
# before constraints must be put in place.

# t-Test Calculation
t_stat, p_val = stats.ttest_rel(df['Pre-Test'], df['Post-Test'])

# Display Results
print(f"Pre-Test Mean: {pre_mean}, Post-Test Mean: {post_mean}")
print(f"Pre-Test Std Dev: {pre_std:.2f}, Post-Test Std Dev: {post_std:.2f}")
print(f"t-Statistic: {t_stat}, p-value: {p_val}")

# Visualization with Matplotlib and Seaborn
plt.figure(figsize=(10,5))

# Visualize the distribution of scores
# plt.figure()
sns.kdeplot(df['Pre-Test'], label="Pre-Test", fill=True)
sns.kdeplot(df['Post-Test'], label="Post-Test", fill=True)
plt.title("Distribution of Pre-Test and Post-Test Scores")
plt.xlabel("Score")
plt.ylabel("Density")
plt.legend()

plt.show()
# Out:
# Pre-Test Mean: 57.56666666666667, Post-Test Mean: 60.53333333333333
# Pre-Test Std Dev: 12.06, Post-Test Std Dev: 12.58
# t-Statistic: -2.4603043670100675, p-value: 0.02007893224154974

# %% [markdown]
# ### **T Test Results:**
#
# - **Significant Results:**
#   If the t-test shows that the post-test scores are significantly higher (p < 0.05), it means that the intervention had a meaningful impact.
#
# - **Non-Significant Results:**
#   If p > 0.05, the intervention might not have been as effective, and the change in scores could be due to chance.
#
# ---
#
# - **Sample Application:**
#   - It tells us if the difference in pre-test and post-test scores is likely to be real or if it could have occurred by chance.
#   - When conducting research or evaluating programs, a p-value less than 0.05 is typically considered statistically significant.
# - **Example:**
#   - A t-test result showing p = 0.02 indicates that there’s only a 2% probability that the observed differences occurred by chance, meaning the program likely caused the improvement.

# %% [markdown]
# ---
#
# ### **Effect Size:**
#
# - [Effect size](https://www.scribbr.com/statistics/effect-size/) tells you how meaningful the relationship between variables or the difference between groups is.
#
# - A large effect size means that a research finding has practical significance, while a small effect size indicates limited practical applications.

# %% [markdown]
# ### Why does effect size matter?
#
# - While statistical significance shows that an effect exists in a study, practical significance shows that the effect is large enough to be meaningful in the real world.
#
# - Statistical significance is denoted by p-values whereas practical significance is represented by effect sizes.

# %% [markdown]
# ---
#
# ### **Calculate the effect size:**
#
# - To calculate the effect size and understand the magnitude of improvement, you can compute Cohen’s d:

# %% [markdown]
# ---
#
# ### **Cohen's d.**
#
# ### Calculating Cohen's d for a Paired t-Test
#
# Calculating **Cohen's d** for a paired t-test is a great way to measure the effect size when comparing pre-test and post-test scores from the same subjects.
#
# ---
#
# ### Step 1: Understand / collect the data
# Two sets of data from the same subjects:
#
# - **Pre-Test Scores:** Scores before an intervention (e.g., training, course).
# - **Post-Test Scores:** Scores after the intervention.
#
# ### Step 2: Calculate the Differences
#
# **Formula**:
#
# ![image.png](attachment:image.png)
#
# **Where**:
# - **Post-Test**: The scores after the intervention.
# - **Pre-Test**: The scores before the intervention.
#
# Calculate the difference for each participant. This tells you how much each participant's score changed due to the intervention.
#
# ---
#
# ### Step 3: Calculate the Mean of the Differences
#
# **Formula**:
#
# ![image-2.png](attachment:image-2.png)
#
# **Where**:
#
# ![image-3.png](attachment:image-3.png)
#
# The mean of the differences is the average change in scores across all participants. This value will help us understand the overall effect of the intervention.
#
# ---
#
# ### Step 4: Calculate the Standard Deviation of the Differences
#
# **Formula**:
#
# ![image-4.png](attachment:image-4.png)
#
# **Where**:
#
# ![image-5.png](attachment:image-5.png)
#
# The standard deviation shows how spread out the differences are. A larger standard deviation indicates more variability in the changes of scores.
#
# ---
#
# ### Step 5: Calculate Cohen's d
#
# **Formula**:
#
# ![image-6.png](attachment:image-6.png)
#
# **Where**:
#
# ![image-7.png](attachment:image-7.png)
#
# Cohen's d tells you how strong the effect of the intervention was, expressed in standard deviation units. A larger Cohen's d indicates a greater effect size.
#
# ---

# %%
# Calculating Cohen's d

# Calculate the differences
differences = df['Post-Test'] - df['Pre-Test']

# Calculate the mean and standard deviation of the differences
mean_diff = np.mean(differences)
std_diff = np.std(differences, ddof=1)  # Using ddof=1 for sample standard deviation ( for paired t test )

# Calculate Cohen's d
cohens_d = mean_diff / std_diff

print(f"Cohen's d: {cohens_d}")
# Out:
# Cohen's d: 0.44918806671329436

# %% [markdown]
# ---
#
# ### **Types of Pretest-Posttest Designs**
#
# #### **1. Randomized Control Group Pretest-Posttest**:
# - In this design, participants are **randomly assigned** to two groups:
#    - **Treatment Group**: Receives the intervention.
#    - **Control Group**: Does not receive the intervention.
# - Both groups take a **pretest** and a **posttest**.
# - This design helps establish whether the treatment caused any changes by comparing the difference in the scores from pretest to posttest between the two groups.
#
# #### **2. Nonrandomized Control Group Pretest-Posttest**:
# - Similar to the above design but **without random assignment**.
# - Pretest and posttest scores are still used for both groups, but since the groups are not randomly assigned, there might be **bias**.
#
# #### **3. Randomized Solomon Four-Group Design**:
# - **Four groups** are used:
#    1. **Pretest + Treatment**: This group takes a pretest, receives intervention, then takes a posttest.
#    2. **Pretest + Control**: This group takes a pretest, does not receive intervention, then takes a posttest.
#    3. **No Pretest + Treatment**: This group skips the pretest, receives intervention, and then takes a posttest.
#    4. **No Pretest + Control**: This group skips the pretest, does not receive intervention, and then takes a posttest.
#
# - **Purpose**: This design allows researchers to see whether taking the pretest itself has an effect on the results (a testing effect).
#
#
# ---
#
# #### Example illustration of results from Randomized Solomon Four-Group design

# %%
# Simulate data for the four-group design
group_data = {
    'Group': ['Pretest + Treatment', 'Pretest + Control', 'No Pretest + Treatment', 'No Pretest + Control'],
    'Pretest_Score': [np.nan, 75, np.nan, 70],
    'Posttest_Score': [85, 78, 88, 72]
}

# Convert the data into a DataFrame
group_df = pd.DataFrame(group_data)

# Create a heatmap for comparison of group scores
plt.figure(figsize=(8, 4))
sns.heatmap(group_df.set_index('Group'), annot=True, cmap='Blues', linewidths=0.5)
plt.title('Randomized Solomon Four-Group Design Scores')
plt.show()

# %% [markdown]
# ### **What does this heatmap show?**:
#
# - **Heatmap Rows**: Each row corresponds to one of the four groups (Pretest + Treatment, Pretest + Control, No Pretest + Treatment, No Pretest + Control).
#
# - **Pretest and Posttest Scores**: The heatmap shows the scores in each stage (pretest and posttest):
#
# - **Blank Values**: Groups that didn't take the pretest (like "No Pretest + Treatment" and "No Pretest + Control") show **Blank** in the heatmap for the pretest column. This visually emphasizes that those groups skipped the pretest phase.
#
# - **Color Gradient**: The intensity of the colors represents the scores, with darker blues representing higher scores and lighter blues representing lower scores.
#
# - "This design helps to determine if the pretest itself has any influence on the posttest results. By comparing the groups that took the pretest with those that didn't, we can see whether the act of taking the pretest affects learning or performance."

# %% [markdown]
# ---
#
# ### **Limitations of Pre-Test and Post-Test Comparisons**
#
# - **Limitations:**
#   Results can be affected by external factors like participant motivation, external study, or fatigue.
# - Some students may perform worse on the post-test due to distractions or stress, not necessarily because they didn’t learn from the intervention.
# - **Example:**
#   In a classroom, students who didn’t sleep well the night before the post-test may score lower, even if they learned from the lesson.

# %% [markdown]
# ---
#
# ### **Pros and Cons of Pretest-Posttest**
#
# **Pros:**
# - **Clear Comparison Between Before and After:**
#   - "One of the major advantages is that it allows for a **clear comparison** of participants' performance before and after the intervention. This can provide insightful data on how effective the treatment has been."
#
# - **Good for Measuring Change Over Time:**
#   - "Additionally, this design is particularly useful for **measuring change over time**. It enables researchers to see how much improvement has occurred, making it valuable for evaluating educational programs, therapies, or any interventions."
#
#
# **Cons:**
# - **Testing Effect:**
#   - "However, there are some drawbacks. One significant issue is the **testing effect**. If participants are familiar with the test format or content, their scores may improve simply due to practice rather than the effectiveness of the treatment."
#
# - **May Not Account for All Variables:**
#   - "Another limitation is that pretest-posttest designs might not account for all confounding variables. Factors outside the treatment could influence the results, leading to inaccurate conclusions."

# %% [markdown]
# ---
#
# ### **Conclusion**
#
# - Pre-test and post-test evaluations are essential tools for assessing programs, treatments and interventions.
# - Comparing the scores helps determine whether the program was effective and whether the participants gained new knowledge or skills.
# - Statistical methods such as t-tests help us analyze the data to draw meaningful conclusions.

# %% [markdown]
# ---
#
# ## References
#
# ![image.png](attachment:image.png)
# - ##### **Newbold, P., Carlson, W. L., & Thorne, B. (2019).** *Statistics for Business and Economics* (9th ed.). Pearson.
# ---
# ![image-2.png](attachment:image-2.png)
# - ##### **Moore, D. S., McCabe, G. P., & Craig, B. A. (2017).** *Introduction to the Practice of Statistics* (9th ed.). W. H. Freeman.
# ---
# ![image-3.png](attachment:image-3.png)
# - ##### **Field, A., Miles, J., & Field, Z. (2012).** *Discovering Statistics Using R*.
# ---
# ![image-4.png](attachment:image-4.png)
# - **McKinney, W. (2017).** *Python for Data Analysis* (2nd ed.). O'Reilly Media.
# ---
# ![image-5.png](attachment:image-5.png)
# - **Sullivan, M. (2018).** *Statistics: Informed Decisions Using Data* (5th ed.). Pearson.

# %% [markdown]
# ---
#
# ![image.png](attachment:image.png)
#
# - **Statistics" by David Freedman, Robert Pisani, and Roger Purves**
#
# ---
#
# ![image-2.png](attachment:image-2.png)
#
# - **"Mathematical Statistics with Applications" by Dennis Wackerly, William Mendenhall, and Richard L. Scheaffer**
